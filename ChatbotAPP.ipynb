# %%
# !pip install openai

# %%
# !pip install gradio

# %%
import openai
import gradio as gr

# Set your OpenAI API key
openai.api_key = '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'

# Function to generate a response
def generate_response(prompt):
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=1024,  # Adjust max_tokens as needed
        temperature=0.7  # Adjust temperature as needed
    )

    # Check for errors in the OpenAI response
    print(response)  # Add this line to print the response

    if 'choices' in response and response['choices']:
        return response['choices'][0]['text'].strip()
    else:
        return "Error: Unable to generate a response."

    # Check for errors in the OpenAI response
    if 'choices' in response and response['choices']:
        return response['choices'][0]['text'].strip()
    else:
        return "Error: Unable to generate a response."

# Gradio Interface
iface = gr.Interface(
    fn=generate_response,
    inputs=[
        gr.Textbox(lines=7, label="Input"),
    ],
    outputs=gr.Textbox(label="Output"),
    title="Mental Health Chatbot App",
    description="Ask me anything!"
)
iface.launch(debug=True)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://c93e2cd17e7c5ef81f.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://c93e2cd17e7c5ef81f.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/queueing.py", line 495, in call_prediction
#     output = await route_utils.call_process_api(
# ...
